# %% [markdown]
# # Clinical and Imaging Analyses to Predict Alzheimer's Disease
#
# ## Model Metrics

# %% [markdown]
# ### A. Cross-sectional Study

# %% [markdown]
# The **K-nearest Neighbors Model** is the model being recommended for the Cross-sectional study from the analyses performed.

# %% [markdown]
# The following was used to tune the model:
#
# * optimal k value: k = 3

# %% [markdown]
# After tuning the model, several metrics were determined using the Confusion Matrix (Figure 1), and they are summarized in Table 1.

# %% [markdown]
# #### Figure 1. KNN model Confusion Matrix

# %% [markdown]
# ![KNN%20confusion%20matrix.png](attachment:KNN%20confusion%20matrix.png)

# %% [markdown]
# #### Table 1. Cross-sectional Study Model Metrics

# %% [markdown]
# ![A%20model%20metrics.png](attachment:A%20model%20metrics.png)

# %% [markdown]
# ### B. Longitudinal Study

# %% [markdown]
# The **One vs Rest (Multi-Layer Perceptron) Model** is the model being recommended for the Longitudinal study from the analyses performed.

# %% [markdown]
# The following was used to tune the model:
#
# * hidden layers sizes: (30, 30, 30)

# %% [markdown]
# After tuning the model, several metrics were determined using the Confusion Matrix (Figure 2), and they are summarized in Table 2.

# %% [markdown]
# #### Figure 2. One vs Rest (MLP) model Confusion Matrix

# %% [markdown]
# ![Ovr%20MLP%20lon%20Regression%20Matrix.png](attachment:Ovr%20MLP%20lon%20Regression%20Matrix.png)

# %% [markdown]
# #### Table 2. Longitudinal Study Model Metrics

# %% [markdown]
# ![B%20model%20metrics.png](attachment:B%20model%20metrics.png)

# %% [markdown]
# ### C. Imaging Study

# %% [markdown]
# The **Convolutional Neural Network (CNN) Model** is the model being recommended for the Imaging study from the analyses performed.

# %% [markdown]
# After running the model on training, validation, and testing image sets, the model had a **95.72% accuracy on the validation set** and **95.95% accuracy on the testing set**.

# %% [markdown]
# #### Table 3. Imaging Study Model Metrics

# %% [markdown]
# ![C%20model%20metrics.png](attachment:C%20model%20metrics.png)
